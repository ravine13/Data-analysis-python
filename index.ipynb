# %% [markdown]
# # Import Necessary Libraries

# %%
# import pandas, matplotlib, seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Datasets

# %%
# Load Shopping Trends dataset
df = pd.read_csv('shopping_trends.zip', compression='zip')

# %% [markdown]
# ## Preview Dataframe

# %%
# Preview Dataset
df.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %% [markdown]
# ## Check Data Types

# %%
# check data types in dataframe
df.dtypes
# Out:
# Unnamed: 0               int64
# CustomerID             float64
# Gender                  object
# Location                object
# Tenure_Months          float64
# Transaction_ID         float64
# Transaction_Date        object
# Product_SKU             object
# Product_Description     object
# Product_Category        object
# Quantity               float64
# Avg_Price              float64
# Delivery_Charges       float64
# Coupon_Status           object
# GST                    float64
# Date                    object
# Offline_Spend          float64
# Online_Spend           float64
# Month                    int64
# Coupon_Code             object
# Discount_pct           float64
# dtype: object

# %% [markdown]
# ## Check for Missing Values

# %%
# check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %% [markdown]
# ## Drop Missing Values

# %%
# Drop all missing values from dataframe
df = df.dropna()

# %% [markdown]
# ## Check for Duplicates

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Compute Descriptive Statistics

# %%
# describe the dataframe
df.describe()
# Out:
#          Unnamed: 0    CustomerID  Tenure_Months  Transaction_ID  \
# count  52524.000000  52524.000000   52524.000000    52524.000000
# mean   26372.364176  15345.347213      26.140393    32445.093367
# std    15232.596810   1766.862675      13.473500     8654.724704
# min        0.000000  12346.000000       2.000000    16679.000000
# 25%    13170.750000  13869.000000      15.000000    25404.000000
# 50%    26361.500000  15311.000000      27.000000    32678.000000
# 75%    39557.250000  16996.000000      37.000000    39174.250000
# max    52923.000000  18283.000000      50.000000    48497.000000
#
#            Quantity     Avg_Price  Delivery_Charges           GST  \
# count  52524.000000  52524.000000      52524.000000  52524.000000
# mean       4.500171     52.429089         10.476922      0.137433
# std       20.159985     64.156649         19.343153      0.045865
# min        1.000000      0.390000          0.000000      0.050000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
# Group by 'Gender' and compute the average 'Avg_Price' for each group
avg_price_by_gender = df.groupby('Gender')['Avg_Price'].mean()

# Group by 'Gender' and compute the sum of 'Quantity' for each group
quantity_by_gender = df.groupby('Gender')['Quantity'].mean()

print("Average Price by Gender:\n", avg_price_by_gender)
print("\nQuantity by Gender:\n", quantity_by_gender)
# Out:
# Average Price by Gender:
#  Gender
# F    51.811230
# M    53.453809
# Name: Avg_Price, dtype: float64
#
# Quantity by Gender:
#  Gender
# F    4.606952
# M    4.323075
# Name: Quantity, dtype: float64

# %% [markdown]
# ## Average Price by Gender

# %%
# Group by 'Gender' and compute the average 'Avg_Price' for each group
avg_price_by_gender = df.groupby('Gender')['Avg_Price'].mean().reset_index()

# Create the bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Gender', y='Avg_Price', hue='Gender', data=avg_price_by_gender, palette='viridis', legend=False)

# Annotate the bars with the average price values
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

# Add titles and labels
plt.title('Average Price by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Price')

# Show the plot
plt.show()

# %% [markdown]
# # Average Quantity by Gender

# %%
# Group by 'Gender' and compute the mean 'Quantity' for each group
mean_quantity_by_gender = df.groupby('Gender')['Quantity'].mean().reset_index()

# Create the bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Gender', y='Quantity', hue='Gender', data=mean_quantity_by_gender, palette='viridis', legend=False)

# Annotate the bars with the mean quantity values
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

# Add titles and labels
plt.title('Mean Quantity by Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Quantity')

# Show the plot
plt.show()

# %% [markdown]
# ## Average Price Over Time

# %%
# Convert 'Transaction_Date' to datetime
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])

# 1. Line Graph: Average Price over Time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Transaction_Date', y='Avg_Price', data=df)
plt.title('Average Price Over Time')
plt.xlabel('Transaction Date')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Quantity v. Avg Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Quantity', y='Avg_Price', data=df)
plt.title('Quantity vs. Average Price')
plt.xlabel('Quantity')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ## Distribution of Tenure Months

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Tenure_Months'], bins=30, kde=True)
plt.title('Distribution of Tenure Months')
plt.xlabel('Tenure Months')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Average Spend by Gender: Online vs. Offline

# %%
# Calculate the average spend for online and offline
avg_spend = df.groupby('Gender')[['Offline_Spend', 'Online_Spend']].mean().reset_index()

# Melt the DataFrame to have a long format for seaborn
avg_spend_melted = avg_spend.melt(id_vars='Gender', value_vars=['Offline_Spend', 'Online_Spend'],
                                  var_name='Spend_Type', value_name='Average_Spend')

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Gender', y='Average_Spend', hue='Spend_Type', data=avg_spend_melted, palette='viridis')

# Add titles and labels
plt.title('Average Spend by Gender: Online vs. Offline')
plt.xlabel('Gender')
plt.ylabel('Average Spend')

# Show the plot
plt.show()
